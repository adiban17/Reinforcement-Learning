# %% [markdown]
# <a href="https://colab.research.google.com/github/adiban17/Reinforcement-Learning/blob/main/HuggytheDog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version

# %%
# !git clone --branch release_21 https://github.com/Unity-Technologies/ml-agents.git

# %%
# !python --version

# %%
# we need python 3.10.12 to run ml-agents

# 1. Install Python 3.10
# !sudo apt-get update -y
# !sudo apt-get install python3.10 python3.10-distutils -y

# 2. Register both versions with update-alternatives
# Assuming Colab's default is 3.12, we give 3.10 priority 1
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.12 2

# 3. Manually select Python 3.10 (Enter '1' when prompted)
# !sudo update-alternatives --config python3

# %%
# 1. Download and install pip for 3.10
# !curl https://bootstrap.pypa.io/get-pip.py -o get-pip.py
# !python3 get-pip.py

# 2. Reinstall Colab kernel dependencies for Python 3.10
# !python3 -m pip install ipython ipykernel jupyter_console google-colab

# %%
# !python --version

# %%
# %%capture
# installing dependencies
# %cd ml-agents
# !pip install -e ./ml-agents-envs
# !pip install -e ./ml-agents

# %%
# !mkdir ./trained-envs-executables
# !mkdir ./trained-envs-executables/linux

# %%
# !wget "https://github.com/huggingface/Huggy/raw/main/Huggy.zip" -O ./trained-envs-executables/linux/Huggy.zip

# %%
# %%capture
# !unzip -d ./trained-envs-executables/linux/ ./trained-envs-executables/linux/Huggy.zip

# %%
# !chmod -R 755 ./trained-envs-executables/linux/Huggy

# %%
import os
os.environ['PYTHONPATH'] = os.getcwd() + ':' + os.environ.get('PYTHONPATH', '')

# !python -m mlagents.trainers.learn ./config/ppo/Huggy.yaml --env=./trained-envs-executables/linux/Huggy/Huggy --run-id="Huggy2" --no-graphics

# %%
# !pip install attrs

# %%
# !pip install onnxscript
